# %%
import numpy as np
import random
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

# Define SARSA parameters
alpha = 0.1  # Learning rate
gamma = 0.95  # Discount factor
epsilon = 0.1  # Exploration rate (decay this over time for more exploitation)

# Define BEO parameters
population_size = 50  # Number of individuals in the population
n_iterations = 100  # Number of optimization iterations
penalty_weight = 0.15  # Penalty weight for selecting too many features

# Load the dataset
file_path = "/kaggle/input/pcos-ml/PCOS_data_without_infertility.xlsx"
df = pd.read_excel(file_path, sheet_name="Full_new")

# Data Preprocessing
df = df.drop(columns=['Sl. No', 'Patient File No.', 'Unnamed: 44'])
df = df.apply(pd.to_numeric, errors='coerce')
df.fillna(df.median(), inplace=True)

# Encode categorical columns
le = LabelEncoder()
categorical_columns = ['Blood Group', 'Cycle(R/I)', 'Pregnant(Y/N)', 
                       'Weight gain(Y/N)', 'hair growth(Y/N)', 
                       'Skin darkening (Y/N)', 'Hair loss(Y/N)', 
                       'Pimples(Y/N)', 'Fast food (Y/N)', 
                       'Reg.Exercise(Y/N)']
for col in categorical_columns:
    if col in df.columns:
        df[col] = le.fit_transform(df[col])

# Split into features and target
X = df.drop(columns=['PCOS (Y/N)'])
y = df['PCOS (Y/N)']

# Use all features
all_features = X.columns.tolist()
n_features = len(all_features)
n_actions = n_features  # One action per feature (either include or exclude)

# Initialize population (binary representation of feature subsets)
population = np.random.randint(2, size=(population_size, n_features))

# SARSA Q-table initialization
Q = np.zeros((population_size, n_actions))

def evaluate_solution(solution, X_train, y_train, X_test, y_test):
    """Evaluate the accuracy of a solution (feature subset) and penalize for too many features."""
    # Use only the selected features from the solution
    selected_columns = [all_features[i] for i in range(len(solution)) if solution[i] == 1]
    if len(selected_columns) == 0:
        return 0  # If no features selected, return zero accuracy
    
    # Fit a simple model (e.g., XGBoost) on the selected features
    model = xgb.XGBClassifier(eval_metric='mlogloss')
    model.fit(X_train[selected_columns], y_train)
    accuracy = model.score(X_test[selected_columns], y_test)
    
    # Apply penalty for number of selected features (objective: fewer features, high accuracy)
    penalty = penalty_weight * len(selected_columns)
    
    return accuracy - penalty  # Objective: maximize accuracy, minimize features

# BEO + SARSA optimization loop
for iteration in range(n_iterations):
    for i in range(population_size):
        # Select an action (flip a feature on/off)
        if random.uniform(0, 1) < epsilon:  # Exploration
            action = np.random.randint(n_actions)
        else:  # Exploitation (SARSA policy)
            action = np.argmax(Q[i])
        
        # Apply the action (flip the feature)
        new_population = np.copy(population)
        new_population[i][action] = 1 - new_population[i][action]
        
        # Evaluate the new solution
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
        reward = evaluate_solution(new_population[i], X_train, y_train, X_test, y_test)
        
        # SARSA: Update Q-value
        next_action = np.argmax(Q[i])  # Choose next action (greedy)
        next_reward = evaluate_solution(new_population[i], X_train, y_train, X_test, y_test)
        Q[i][action] += alpha * (reward + gamma * next_reward - Q[i][action])
        
        # Print the current selected features for each iteration
        selected_columns = [all_features[idx] for idx, val in enumerate(new_population[i]) if val == 1]
        print(f"Iteration {iteration+1}, Individual {i+1}, Selected Features: {selected_columns}")

# Get the final solution (best individual from the population)
best_individual_idx = np.argmax([evaluate_solution(population[i], X_train, y_train, X_test, y_test) for i in range(population_size)])
final_solution = population[best_individual_idx]

# Final selected features after optimization
final_selected_features = [all_features[idx] for idx, val in enumerate(final_solution) if val == 1]
print(f"Final Selected Features: {final_selected_features}")
# Out:
# Iteration 1, Individual 1, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'RR (breaths/min)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 2, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'Waist:Hip Ratio', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 1, Individual 3, Selected Features: ['Weight (Kg)', 'Blood Group', 'Cycle(R/I)', 'Cycle length(days)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)']
# Iteration 1, Individual 4, Selected Features: ['Height(Cm) ', 'BMI', 'Blood Group', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'Hip(inch)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 1, Individual 5, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 6, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'FSH/LH', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (L) (mm)']
# Iteration 1, Individual 7, Selected Features: ['Height(Cm) ', 'BMI', 'Blood Group', 'RR (breaths/min)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 8, Selected Features: ['Weight (Kg)', 'Blood Group', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'Waist(inch)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 9, Selected Features: [' Age (yrs)', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle length(days)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 10, Selected Features: ['Weight (Kg)', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle(R/I)', 'FSH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)']
# Iteration 1, Individual 11, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Blood Group', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'Waist:Hip Ratio', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)']
# Iteration 1, Individual 12, Selected Features: ['Height(Cm) ', 'BMI', 'RR (breaths/min)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Endometrium (mm)']
# Iteration 1, Individual 13, Selected Features: [' Age (yrs)', 'BMI', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 14, Selected Features: ['Height(Cm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 15, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Endometrium (mm)']
# Iteration 1, Individual 16, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 1, Individual 17, Selected Features: ['Weight (Kg)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 1, Individual 18, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Hb(g/dl)', 'Cycle length(days)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 19, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)']
# Iteration 1, Individual 20, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 1, Individual 21, Selected Features: [' Age (yrs)', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Follicle No. (R)']
# Iteration 1, Individual 22, Selected Features: ['Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle length(days)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 23, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 24, Selected Features: [' Age (yrs)', 'BMI', 'Hb(g/dl)', 'No. of aborptions', 'FSH(mIU/mL)', 'Hip(inch)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 1, Individual 25, Selected Features: ['Weight (Kg)', 'BMI', 'Cycle(R/I)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 26, Selected Features: ['Weight (Kg)', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)']
# Iteration 1, Individual 27, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Hb(g/dl)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 28, Selected Features: ['Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 1, Individual 29, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Cycle length(days)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (L) (mm)']
# Iteration 1, Individual 30, Selected Features: ['Weight (Kg)', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'TSH (mIU/L)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Avg. F size (L) (mm)']
# Iteration 1, Individual 31, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 1, Individual 32, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Pulse rate(bpm) ', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 33, Selected Features: ['Height(Cm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 34, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'RR (breaths/min)', 'Cycle length(days)', 'No. of aborptions', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRG(ng/mL)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 35, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 1, Individual 36, Selected Features: [' Age (yrs)', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)']
# Iteration 1, Individual 37, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 38, Selected Features: ['BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 1, Individual 39, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'RR (breaths/min)', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'LH(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 40, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 1, Individual 41, Selected Features: ['Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Endometrium (mm)']
# Iteration 1, Individual 42, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Cycle(R/I)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 43, Selected Features: [' Age (yrs)', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 44, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 45, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 46, Selected Features: ['Blood Group', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 47, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'TSH (mIU/L)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 1, Individual 48, Selected Features: ['Weight (Kg)', 'BMI', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 49, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Follicle No. (L)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 1, Individual 50, Selected Features: ['Height(Cm) ', 'BMI', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 1, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'RR (breaths/min)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 2, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 2, Individual 3, Selected Features: [' Age (yrs)', 'Blood Group', 'Cycle(R/I)', 'Cycle length(days)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)']
# Iteration 2, Individual 4, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Blood Group', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'Hip(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 2, Individual 5, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 6, Selected Features: ['Height(Cm) ', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'LH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (L) (mm)']
# Iteration 2, Individual 7, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'RR (breaths/min)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 8, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Blood Group', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'Waist(inch)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 9, Selected Features: ['Weight (Kg)', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle length(days)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 10, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle(R/I)', 'FSH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)']
# Iteration 2, Individual 11, Selected Features: ['Blood Group', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'Waist:Hip Ratio', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)']
# Iteration 2, Individual 12, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Endometrium (mm)']
# Iteration 2, Individual 13, Selected Features: ['BMI', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 14, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 15, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Endometrium (mm)']
# Iteration 2, Individual 16, Selected Features: ['Height(Cm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 2, Individual 17, Selected Features: [' Age (yrs)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 2, Individual 18, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'Blood Group', 'Hb(g/dl)', 'Cycle length(days)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 19, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)']
# Iteration 2, Individual 20, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 21, Selected Features: ['Weight (Kg)', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Follicle No. (R)']
# Iteration 2, Individual 22, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle length(days)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 23, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 24, Selected Features: ['Weight (Kg)', 'BMI', 'Hb(g/dl)', 'No. of aborptions', 'FSH(mIU/mL)', 'Hip(inch)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 2, Individual 25, Selected Features: [' Age (yrs)', 'BMI', 'Cycle(R/I)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 26, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'FSH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)']
# Iteration 2, Individual 27, Selected Features: ['Hb(g/dl)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 28, Selected Features: ['Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 2, Individual 29, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Cycle length(days)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (L) (mm)']
# Iteration 2, Individual 30, Selected Features: [' Age (yrs)', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'TSH (mIU/L)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Avg. F size (L) (mm)']
# Iteration 2, Individual 31, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 2, Individual 32, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Pulse rate(bpm) ', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 33, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 34, Selected Features: ['Height(Cm) ', 'RR (breaths/min)', 'No. of aborptions', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRG(ng/mL)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 35, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Blood Group', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 2, Individual 36, Selected Features: ['Weight (Kg)', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)']
# Iteration 2, Individual 37, Selected Features: ['Height(Cm) ', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 38, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 2, Individual 39, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'RR (breaths/min)', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'LH(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 40, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 2, Individual 41, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Endometrium (mm)']
# Iteration 2, Individual 42, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Cycle(R/I)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 43, Selected Features: ['Weight (Kg)', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 44, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 45, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 46, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Blood Group', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 47, Selected Features: ['Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'TSH (mIU/L)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 2, Individual 48, Selected Features: [' Age (yrs)', 'BMI', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 49, Selected Features: ['BMI', 'Blood Group', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Follicle No. (L)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 2, Individual 50, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 3, Individual 1, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'RR (breaths/min)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 3, Individual 2, Selected Features: ['Height(Cm) ', 'Blood Group', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'Waist:Hip Ratio', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 3, Individual 3, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Cycle(R/I)', 'Cycle length(days)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)']
# Iteration 3, Individual 4, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'Hip(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 3, Individual 5, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'BMI', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 3, Individual 6, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'LH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (L) (mm)']
# Iteration 3, Individual 7, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Blood Group', 'RR (breaths/min)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 3, Individual 8, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Blood Group', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 3, Individual 9, Selected Features: ['Height(Cm) ', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle length(days)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 3, Individual 10, Selected Features: ['Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle(R/I)', 'FSH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)']
# Iteration 3, Individual 11, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Waist(inch)', 'Waist:Hip Ratio', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)']
# Iteration 3, Individual 12, Selected Features: [' Age (yrs)', 'BMI', 'RR (breaths/min)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Endometrium (mm)']
# Iteration 3, Individual 13, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'BMI', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)']
# Iteration 3, Individual 14, Selected Features: [' Age (yrs)', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 3, Individual 15, Selected Features: ['Height(Cm) ', 'BMI', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Endometrium (mm)']
# Iteration 3, Individual 16, Selected Features: ['Weight (Kg)', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 3, Individual 17, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'Cycle length(days)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 3, Individual 18, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Blood Group', 'Hb(g/dl)', 'Cycle length(days)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 3, Individual 19, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)']
# ...
# Iteration 100, Individual 12, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Cycle length(days)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Endometrium (mm)']
# Iteration 100, Individual 13, Selected Features: [' Age (yrs)', 'BMI', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 14, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 15, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'BMI', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Endometrium (mm)']
# Iteration 100, Individual 16, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 100, Individual 17, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 100, Individual 18, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Hb(g/dl)', 'Cycle length(days)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 19, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)']
# Iteration 100, Individual 20, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 21, Selected Features: ['BMI', 'Blood Group', 'Pulse rate(bpm) ', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Follicle No. (R)']
# Iteration 100, Individual 22, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle length(days)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 23, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 24, Selected Features: ['BMI', 'Hb(g/dl)', 'No. of aborptions', 'FSH(mIU/mL)', 'Hip(inch)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 100, Individual 25, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'BMI', 'Hb(g/dl)', 'Cycle(R/I)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 26, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)']
# Iteration 100, Individual 27, Selected Features: ['Weight (Kg)', 'Hb(g/dl)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'FSH/LH', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 28, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 100, Individual 29, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Cycle length(days)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (L) (mm)']
# Iteration 100, Individual 30, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Blood Group', 'RR (breaths/min)', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'LH(mIU/mL)', 'TSH (mIU/L)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Avg. F size (L) (mm)']
# Iteration 100, Individual 31, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'Vit D3 (ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 100, Individual 32, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Pulse rate(bpm) ', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 33, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 34, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'RR (breaths/min)', 'No. of aborptions', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRG(ng/mL)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 35, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 100, Individual 36, Selected Features: ['Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)']
# Iteration 100, Individual 37, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'Follicle No. (L)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 38, Selected Features: [' Age (yrs)', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Endometrium (mm)']
# Iteration 100, Individual 39, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'Blood Group', 'RR (breaths/min)', 'Hb(g/dl)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'LH(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 40, Selected Features: ['Height(Cm) ', 'BMI', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']
# Iteration 100, Individual 41, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Endometrium (mm)']
# Iteration 100, Individual 42, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI', 'RR (breaths/min)', 'Cycle(R/I)', 'No. of aborptions', 'II    beta-HCG(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'Vit D3 (ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 43, Selected Features: ['BMI', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', 'TSH (mIU/L)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 44, Selected Features: ['Weight (Kg)', 'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle length(days)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 45, Selected Features: ['Height(Cm) ', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 46, Selected Features: [' Age (yrs)', 'Blood Group', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 47, Selected Features: ['Weight (Kg)', 'Blood Group', 'Pulse rate(bpm) ', 'Hb(g/dl)', 'Cycle(R/I)', 'Pregnant(Y/N)', '  I   beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'TSH (mIU/L)', 'PRL(ng/mL)', 'RBS(mg/dl)', 'Pimples(Y/N)', 'Fast food (Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (R)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Iteration 100, Individual 48, Selected Features: [' Age (yrs)', 'Weight (Kg)', 'BMI', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions', 'FSH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist:Hip Ratio', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 49, Selected Features: ['Weight (Kg)', 'BMI', 'Blood Group', 'Pulse rate(bpm) ', 'Cycle(R/I)', 'Marraige Status (Yrs)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'PRL(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'hair growth(Y/N)', 'Follicle No. (L)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)']
# Iteration 100, Individual 50, Selected Features: [' Age (yrs)', 'Height(Cm) ', 'BMI', 'Marraige Status (Yrs)', 'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH/LH', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Pimples(Y/N)', 'BP _Systolic (mmHg)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)']
# Final Selected Features: [' Age (yrs)', 'Height(Cm) ', 'RR (breaths/min)', 'No. of aborptions', 'Hip(inch)', 'Waist:Hip Ratio', 'AMH(ng/mL)', 'PRG(ng/mL)', 'Fast food (Y/N)', 'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Endometrium (mm)']
